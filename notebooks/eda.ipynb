# %%
import pandas as pd
import warnings
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

warnings.filterwarnings("ignore")
pd.options.display.max_columns = 100

# %%
# %load_ext watermark

# %%
# %watermark -p pandas,numpy
# Out:
# pandas : 2.2.2
# numpy  : 1.24.3
# plotly : 5.22.0
# seaborn: 0.13.2

# %%
df = pd.read_csv("../data/loan_approval_dataset.csv")

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.dtypes.value_counts()
# Out:
# int64     10
# object     3
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.strip().tolist()

# %%
df.describe().T
# Out:
#                            count          mean           std       min  \
# loan_id                   4269.0  2.135000e+03  1.232498e+03       1.0
# no_of_dependents          4269.0  2.498712e+00  1.695910e+00       0.0
# income_annum              4269.0  5.059124e+06  2.806840e+06  200000.0
# loan_amount               4269.0  1.513345e+07  9.043363e+06  300000.0
# loan_term                 4269.0  1.090045e+01  5.709187e+00       2.0
# cibil_score               4269.0  5.999361e+02  1.724304e+02     300.0
# residential_assets_value  4269.0  7.472617e+06  6.503637e+06 -100000.0
# commercial_assets_value   4269.0  4.973155e+06  4.388966e+06       0.0
# luxury_assets_value       4269.0  1.512631e+07  9.103754e+06  300000.0
# bank_asset_value          4269.0  4.976692e+06  3.250185e+06       0.0
#
#                                 25%         50%         75%         max
# loan_id                      1068.0      2135.0      3202.0      4269.0
# no_of_dependents                1.0         3.0         4.0         5.0
# income_annum              2700000.0   5100000.0   7500000.0   9900000.0
# loan_amount               7700000.0  14500000.0  21500000.0  39500000.0
# loan_term                       6.0        10.0        16.0        20.0
# cibil_score                   453.0       600.0       748.0       900.0
# residential_assets_value  2200000.0   5600000.0  11300000.0  29100000.0
# commercial_assets_value   1300000.0   3700000.0   7600000.0  19400000.0
# luxury_assets_value       7500000.0  14600000.0  21700000.0  39200000.0
# bank_asset_value          2300000.0   4600000.0   7100000.0  14700000.0

# %%
df.shape[0] == df["loan_id"].nunique()
# Out:
# True

# %%
target = "loan_status"
drop = "loan_id"

# %%
cat_cols = [c for c in df.select_dtypes("object").columns.tolist() if c not in target]
num_cols = [c for c in df.select_dtypes(exclude="O").columns.tolist() if c not in drop]

# %%
train_cols = [c for c in df.columns if c not in [target, drop]]

# %%
df.groupby(target)[num_cols].mean()
# Out:
#              no_of_dependents  income_annum   loan_amount  loan_term  \
# loan_status
# Approved             2.474774  5.025904e+06  1.524725e+07  10.397590
# Rejected             2.538128  5.113825e+06  1.494606e+07  11.728456
#
#              cibil_score  residential_assets_value  commercial_assets_value  \
# loan_status
# Approved      703.461973              7.399812e+06             5.001355e+06
# Rejected      429.468072              7.592498e+06             4.926720e+06
#
#              luxury_assets_value  bank_asset_value
# loan_status
# Approved            1.501660e+07      4.959526e+06
# Rejected            1.530694e+07      5.004960e+06

# %%
df[target].value_counts(normalize=True)
# Out:
# loan_status
# Approved    0.62216
# Rejected    0.37784
# Name: proportion, dtype: float64

# %%
df.isna().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
# https://stackoverflow.com/a/50703596
corr = df.drop(drop, axis=1)[num_cols].corr()
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
# corr[mask] = np.nan
(
    corr.style.background_gradient(cmap="coolwarm", axis=None, vmin=-1, vmax=1)
    .highlight_null(color="#f1f1f1")  # Color NaNs grey
    .format(precision=2)
)
# Out:
# <style type="text/css">
# #T_fda9d_row0_col0, #T_fda9d_row1_col1, #T_fda9d_row2_col2, #T_fda9d_row3_col3, #T_fda9d_row4_col4, #T_fda9d_row5_col5, #T_fda9d_row6_col6, #T_fda9d_row7_col7, #T_fda9d_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fda9d_row0_col1, #T_fda9d_row0_col5, #T_fda9d_row0_col7, #T_fda9d_row1_col0, #T_fda9d_row3_col4, #T_fda9d_row4_col3, #T_fda9d_row5_col0, #T_fda9d_row7_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_fda9d_row0_col2, #T_fda9d_row0_col6, #T_fda9d_row2_col0, #T_fda9d_row3_col6, #T_fda9d_row4_col6, #T_fda9d_row6_col0, #T_fda9d_row6_col3, #T_fda9d_row6_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_fda9d_row0_col3, #T_fda9d_row1_col4, #T_fda9d_row2_col4, #T_fda9d_row3_col0, #T_fda9d_row4_col1, #T_fda9d_row4_col2, #T_fda9d_row4_col5, #T_fda9d_row5_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_fda9d_row0_col4, #T_fda9d_row4_col0, #T_fda9d_row4_col8, #T_fda9d_row8_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_fda9d_row0_col8, #T_fda9d_row1_col3, #T_fda9d_row2_col3, #T_fda9d_row3_col1, #T_fda9d_row3_col2, #T_fda9d_row3_col5, #T_fda9d_row3_col7, #T_fda9d_row5_col3, #T_fda9d_row7_col3, #T_fda9d_row8_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_fda9d_row1_col2, #T_fda9d_row1_col7, #T_fda9d_row2_col1, #T_fda9d_row7_col1 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_fda9d_row1_col5, #T_fda9d_row1_col6, #T_fda9d_row5_col1, #T_fda9d_row6_col1 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_fda9d_row1_col8, #T_fda9d_row8_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_fda9d_row2_col5, #T_fda9d_row5_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_fda9d_row2_col6, #T_fda9d_row6_col2 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_fda9d_row2_col7, #T_fda9d_row7_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_fda9d_row2_col8, #T_fda9d_row7_col8, #T_fda9d_row8_col2, #T_fda9d_row8_col7 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_fda9d_row3_col8, #T_fda9d_row8_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_fda9d_row4_col7, #T_fda9d_row7_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_fda9d_row5_col6, #T_fda9d_row6_col5 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_fda9d_row5_col7, #T_fda9d_row6_col7, #T_fda9d_row7_col5, #T_fda9d_row7_col6 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_fda9d_row5_col8, #T_fda9d_row8_col5 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_fda9d_row6_col8, #T_fda9d_row8_col6 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fda9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fda9d_level0_col0" class="col_heading level0 col0" >no_of_dependents</th>
#       <th id="T_fda9d_level0_col1" class="col_heading level0 col1" >income_annum</th>
#       <th id="T_fda9d_level0_col2" class="col_heading level0 col2" >loan_amount</th>
#       <th id="T_fda9d_level0_col3" class="col_heading level0 col3" >loan_term</th>
#       <th id="T_fda9d_level0_col4" class="col_heading level0 col4" >cibil_score</th>
#       <th id="T_fda9d_level0_col5" class="col_heading level0 col5" >residential_assets_value</th>
#       <th id="T_fda9d_level0_col6" class="col_heading level0 col6" >commercial_assets_value</th>
#       <th id="T_fda9d_level0_col7" class="col_heading level0 col7" >luxury_assets_value</th>
#       <th id="T_fda9d_level0_col8" class="col_heading level0 col8" >bank_asset_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fda9d_level0_row0" class="row_heading level0 row0" >no_of_dependents</th>
#       <td id="T_fda9d_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_fda9d_row0_col1" class="data row0 col1" >0.01</td>
#       <td id="T_fda9d_row0_col2" class="data row0 col2" >-0.00</td>
#       <td id="T_fda9d_row0_col3" class="data row0 col3" >-0.02</td>
#       <td id="T_fda9d_row0_col4" class="data row0 col4" >-0.01</td>
#       <td id="T_fda9d_row0_col5" class="data row0 col5" >0.01</td>
#       <td id="T_fda9d_row0_col6" class="data row0 col6" >-0.00</td>
#       <td id="T_fda9d_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_fda9d_row0_col8" class="data row0 col8" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_fda9d_level0_row1" class="row_heading level0 row1" >income_annum</th>
#       <td id="T_fda9d_row1_col0" class="data row1 col0" >0.01</td>
#       <td id="T_fda9d_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_fda9d_row1_col2" class="data row1 col2" >0.93</td>
#       <td id="T_fda9d_row1_col3" class="data row1 col3" >0.01</td>
#       <td id="T_fda9d_row1_col4" class="data row1 col4" >-0.02</td>
#       <td id="T_fda9d_row1_col5" class="data row1 col5" >0.64</td>
#       <td id="T_fda9d_row1_col6" class="data row1 col6" >0.64</td>
#       <td id="T_fda9d_row1_col7" class="data row1 col7" >0.93</td>
#       <td id="T_fda9d_row1_col8" class="data row1 col8" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_fda9d_level0_row2" class="row_heading level0 row2" >loan_amount</th>
#       <td id="T_fda9d_row2_col0" class="data row2 col0" >-0.00</td>
#       <td id="T_fda9d_row2_col1" class="data row2 col1" >0.93</td>
#       <td id="T_fda9d_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_fda9d_row2_col3" class="data row2 col3" >0.01</td>
#       <td id="T_fda9d_row2_col4" class="data row2 col4" >-0.02</td>
#       <td id="T_fda9d_row2_col5" class="data row2 col5" >0.59</td>
#       <td id="T_fda9d_row2_col6" class="data row2 col6" >0.60</td>
#       <td id="T_fda9d_row2_col7" class="data row2 col7" >0.86</td>
#       <td id="T_fda9d_row2_col8" class="data row2 col8" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_fda9d_level0_row3" class="row_heading level0 row3" >loan_term</th>
#       <td id="T_fda9d_row3_col0" class="data row3 col0" >-0.02</td>
#       <td id="T_fda9d_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_fda9d_row3_col2" class="data row3 col2" >0.01</td>
#       <td id="T_fda9d_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_fda9d_row3_col4" class="data row3 col4" >0.01</td>
#       <td id="T_fda9d_row3_col5" class="data row3 col5" >0.01</td>
#       <td id="T_fda9d_row3_col6" class="data row3 col6" >-0.01</td>
#       <td id="T_fda9d_row3_col7" class="data row3 col7" >0.01</td>
#       <td id="T_fda9d_row3_col8" class="data row3 col8" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_fda9d_level0_row4" class="row_heading level0 row4" >cibil_score</th>
#       <td id="T_fda9d_row4_col0" class="data row4 col0" >-0.01</td>
#       <td id="T_fda9d_row4_col1" class="data row4 col1" >-0.02</td>
#       <td id="T_fda9d_row4_col2" class="data row4 col2" >-0.02</td>
#       <td id="T_fda9d_row4_col3" class="data row4 col3" >0.01</td>
#       <td id="T_fda9d_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_fda9d_row4_col5" class="data row4 col5" >-0.02</td>
#       <td id="T_fda9d_row4_col6" class="data row4 col6" >-0.00</td>
#       <td id="T_fda9d_row4_col7" class="data row4 col7" >-0.03</td>
#       <td id="T_fda9d_row4_col8" class="data row4 col8" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_fda9d_level0_row5" class="row_heading level0 row5" >residential_assets_value</th>
#       <td id="T_fda9d_row5_col0" class="data row5 col0" >0.01</td>
#       <td id="T_fda9d_row5_col1" class="data row5 col1" >0.64</td>
#       <td id="T_fda9d_row5_col2" class="data row5 col2" >0.59</td>
#       <td id="T_fda9d_row5_col3" class="data row5 col3" >0.01</td>
#       <td id="T_fda9d_row5_col4" class="data row5 col4" >-0.02</td>
#       <td id="T_fda9d_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_fda9d_row5_col6" class="data row5 col6" >0.41</td>
#       <td id="T_fda9d_row5_col7" class="data row5 col7" >0.59</td>
#       <td id="T_fda9d_row5_col8" class="data row5 col8" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_fda9d_level0_row6" class="row_heading level0 row6" >commercial_assets_value</th>
#       <td id="T_fda9d_row6_col0" class="data row6 col0" >-0.00</td>
#       <td id="T_fda9d_row

# %%
s = corr.unstack()
so = s.sort_values(kind="quicksort", ascending=False)
so.to_frame("correlation").query(
    "(correlation >= 0.9) & (correlation != 1.0) "
).drop_duplicates("correlation").sort_index(level=0).reset_index().head()
# Out:
#         level_0              level_1  correlation
# 0  income_annum          loan_amount     0.927470
# 1  income_annum  luxury_assets_value     0.929145
